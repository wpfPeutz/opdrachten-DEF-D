# %% [markdown]
# # Condensator Ontwerpopdracht
#
# Bij het vak elektromagnetisme zullen jullie in de eerste paar weken diep ingaan op de elektrostatica. Parallel hieraan zullen we bij het vak DEF-D, naast de fysieke ontwerpopdrachten en colleges, deze simulatie-ontwerpopdracht behandelen. Deze simulatie-opdracht is weer nauw verwoven met de tweede fysieke ontwerpopdracht die in week 3.3 gegeven wordt. Je moet het grootste deel van deze simulatie opdracht afronden voordat je aan de fysieke ontwerpopdracht van week 3.3 begint. Het laatste stuk van deze simulatie opdracht maak je na afloop van de fysieke opdracht. De deadline voor het inleveren van deze simulatie-opdracht is in week 3.4
#
# Je werkt bij deze opdracht in teams die wij indelen. Zoek op Brightspace op met wie je samenwerkt en leg via email contact. Maak goede afspraken over hoe je samen gaat werken.
#
# In deze simulatie opdracht beginnen we met een aantal simulaties van verschillende situaties, die jullie daarna zullen interpreteren. Daarna zal wat essentiële voorbereiding op de tweede fysieke ontwerpopdracht besproken worden. En als laatste zal dieper ingegaan worden op hoe jullie metingen van de tweede ontwerpopdracht afwijken van de theorie.
#
# De opdracht bestaat uit de volgende sub-opdrachten die je moet doen voordat je begint aan de fysieke ontwerpopdracht van week 3.3:
# 1) Een puntlading in de oorsprong.
# 2) Een uniform geladen schijf bestaande uit puntladingen.
# 3) Een geladen schijf op een constant potentiaal.
# 4) Twee geleidende platen op potentiaal $V_1$ and $-V_1$.
# 5) Voorbereidende opdracht voor de DEF ontwerpopdracht.
#
# Na de fysieke ontwerpopdracht van week 3.3 kan je ten slotte het laatste deel doen:
#
# 6) Reflectie opdracht voor na de fysieke ontwerpopdracht.
#
# De opdracht wordt volledig online gedaan, er zullen hiervoor dus ook geen specifieke werkcolleges voor zijn ingeroosterd. Als jullie vragen hebben kunnen jullie die mailen naar het DEF e-mailadres: DEF-TNW@tudelft.nl. Deze opdracht wordt in week 3.4 beoordeeld en herkansingen zijn in week 3.5, zie de studiehandleiding voor details.
#
# Technische Instructies:
# - Git clone (als nog niet gedaan) het DEF repo en maak een branch voor werken aan deze opdracht. Nodig je groepsgenoot uit als collaborator. Hiervoor staat een manual op brightspace.
# - Dit notebook maakt gebruik van een aantal functies die in het bestand ```functions_electrostatics.py``` staan. Dit bestand moet in dezelfde map (folder) staan als dit notebook. Als je git clone doet, gaat dat automatisch goed, maar verplaats dit notebook dus niet naar een andere map, mail het niet naar een mede-student, etc. Als je niet weet wat een map (folder) en een bestand is, bekijk dan [deze tutorial](https://teachbooks.io/files-and-folders/EN/intro.html).
#
# Onderwijs Instructies:
# - Beantwoord de vragen die in dit notebook voor komen direct in dit notebook.
# - Als je iets moet printen op het scherm als antwoord op een vraag, doe dit op een gestructureerde manier met als dat relevant is de eenheid erbij, zoals je geleerd is bij het Inleidend Practicum.
# - Vermijd 'hardcoden' waar mogelijk.
# - Bij elke code cel staat aangegeven of jij hem moet aanpassen of alleen runnen. Lees bij cellen die je moet runnen, maar niet hoeft aan te passen, goed de code door om daarvan te leren en te gebruiken in de cellen die je wel moet aanpassen.
#
# Elektrostatica Opmerkingen:
# - In deze opdracht zullen jullie verschillende problemen bestuderen die as-symmetrie hebben. De opdrachten zullen daardoor, cilindrische coördinaten ($r$,$\phi$,$z$) gebruiken, waarbij $r$ de afstand tot de $z$ as is, $z$ de hoogte en $\phi$ de hoek met de $x$-as. Alle gebruikte problemen zullen ook in de $\phi$ richting symmetrisch zijn en die coördinaat zal dus niet uitmaken.
# - Voor elke sub-opdracht zal eerst het potentiaal bepaald worden en daarna zal het elektrische veld bepaald worden met de "finite difference" methode. Dit is een methode om de afgeleide te nemen van een dataset. Deze methode is geen onderdeel van de leerdoelen van het vak en komt later in je studie aan bod. We gebruiken "finite difference" hier als gereedschap en als voorbeeld van wat je later nog tegen gaat komen.

# %% [markdown]
# Vul de informatie in deze cel in:
#
# | Groep: XX     |  |
# | :-------------|:-------------|
# | Sriman Patlolla| 6393829 |
# | Wolf Peutz| 6436102 |

# %%
# Run deze cel, pas deze niet aan
import numpy as np
import matplotlib.pyplot as plt
from functions_electrostatics import *
#from IPython import display
from IPython.display import Image, display


epsilon0 = 8.854e-12  # permittiviteit van vacuum (F/m)

"""============================================================================================
We first define the size of the domain of calculation and spatial discretization of the domain
"""

# Grid van het rekendomein; het veld wordt berekend in het (r,z)-vlak (asymmetrie):
width_domain = 5  # (m)
height_domain = width_domain  # maximum afstand van de schijf tot de grond, boven en beneden (m)
grid_step = 0.1  # grid stap grootte (m)

# %% [markdown]
# ### 1) Een puntlading in de oorsprong
#
# In deze opdracht gaan we in op een numerieke benadering van het potentiaal en elektrische veld rond een puntlading in de oorsprong.

# %%
# Run deze cel, pas de cel niet aan
charge_one_point = 1e-14  # lading van 1 punt (C)

r, z, B = initialize_plane_grid_for_pt_charge_at_origin(height_domain, width_domain, grid_step)
V = calculate_V_point_charge_at_origin(charge_one_point, r, z)

Er, Ez, normE = compute_E_pt_charge(V, B, grid_step)  # gebruik de centered finite-difference method
# met Er de r-component, Ez de z-component en normE de norm van het elektrische veld

r_for_E = r[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de r-dimensie
z_for_E = z[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de z-dimensie

plot_results_pt_charge_at_origin(Ez, Er, normE, V, r, z, grid_step)

# %% [markdown]
# ##### Vraag 1a Het potentiaal rond een puntlading
#
# 1. Bepaal welke index correspondeert met $z = 0$ m.
# 2. Plot de log van het potentiaal tegen de log van de straal.
# 3. Fit de log van het potentiaal met de log van de straal.
# 4. Print het exponent op een nette manier.

# %%
###
###Hier jouw code###
###
from scipy.optimize import curve_fit
idx_z=find_idx_nearest(z,0)
print("De index bij z=0 voor V is:", idx_z)

r_plot=r[1:]
V_plot=V[idx_z,1:]
log_r=np.log10(r_plot)
log_V=np.log10(V_plot)

def func(r,a,b):
    return a*r+b

popt, pcov = curve_fit(func, log_r, log_V)
a_fit, b_fit = popt
print("De exponent a bij V is:", a_fit)
r_test = np.linspace(np.min(log_r), np.max(log_r),100)
V_test = func(r_test, a_fit, b_fit)

plt.figure()
plt.plot(log_r, log_V,'.')
plt.plot(r_test, V_test,'r-')
plt.xlabel('log10(r) (m)')
plt.ylabel('log10(V) (V)')
plt.title('Log-log plot van potentiaal tegen afstand')
plt.show()
# Out:
# De index bij z=0 voor V is: 50
# De exponent a bij V is: -1.0

# %% [markdown]
# ##### Vraag 1b Het elektrische veld rond een puntlading
# 1. Voer van vraag 1a 2 tot 4 uit voor het elektrische veld.

# %%
###
###Hier jouw code###
###
idx_z_E = find_idx_nearest(z_for_E,0)
print("De index bij z=0 voor E is:", idx_z_E)

r_plot_E = r_for_E[1:]
E_plot = normE[idx_z_E,1:]
log_r_E = np.log10(r_plot_E)
log_E = np.log10(E_plot)

popt_E, pcov_E = curve_fit(func, log_r_E, log_E)
a_fit_E, b_fit_E = popt_E
print("De exponent a voor E is:", a_fit_E)

r_test_E = np.linspace(np.min(log_r_E), np.max(log_r_E),100)
E_test = func(r_test_E, a_fit_E, b_fit_E)

plt.figure()
plt.plot(log_r_E, log_E, '.')
plt.plot(r_test_E, E_test, 'r-')
plt.title('Log-log plot van elektrisch veld tegen afstand')
plt.xlabel('log10(r) (m)')
plt.ylabel('log10(E) (V/m)')
plt.show()
# Out:
# De index bij z=0 voor E is: 49
# De exponent a voor E is: -2.0403594568865167

# %% [markdown]
# ### 2) Een uniform geladen schijf bestaande uit puntladingen
#
# In de code hieronder wordt een geladen schijf gemaakt via het superpositie principe. Dit wordt gedaan door een rooster van punten in de ruimte te creëren, alle punten die voldoen aan $z = 0$ m en $r < R$ krijgen een lading charge_one_point en vanuit hier wordt het potentiaal bepaald. Hier is de $z$-as de as van de schijf en de r as de afstand tot de $z$-as.

# %%
# In vraag 2.1 wordt naar deze cel verwezen.
disk_radius = 3  # (m)
grid_step = 0.1  # (m)
z_coord_DISK = 0  # (m) positie van de schijf op de z-as
inter_charge_distance = grid_step  # (m) afstand tussen punt ladingen

# %%
# Kies uit deze cel een van de variabelen en verander die in de cel hierboven pas deze cel zelf niet aan.
r, z, B = initialize_plane_grid_for_uniformly_charged_disk(height_domain, width_domain, grid_step)

idx_z_zero = np.where(abs(z) < 1e-10)[0]
z_coord_DISK = 0  # (m) positie van de schijf op de z-as
inter_charge_distance = grid_step  # (m) afstand tussen punt ladingen

V, number_point_charges_on_disk = calculate_V_disk_at_origin_uniform_surface_charge_density(z_coord_DISK, charge_one_point, disk_radius, inter_charge_distance, r, z)
Er, Ez, normE = compute_E_disk(V, B, grid_step)  # gebruik de centered finite-difference method

r_for_E = r[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de r-dimensie
z_for_E = z[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de z-dimensie

plot_results_disk(Ez, Er, normE, V, r, z, grid_step, disk_radius, z_coord_DISK, z_coord_DISK)

# %% [markdown]
# #### Vraag 2a
#
# In deze vraag gaan jullie achterhalen wat de variabelen die aan het begin van opgave 2 worden geïnitialiseerd betekenen voor de nauwkeurigheid en snelheid van de code.
# Pas voor deze vraag de code die net onder het kopje vraag 2 staat aan. Run dan die cel en de cel daaronder opnieuw om het resultaat van je aanpassing te zien.
# 1. Wat betekent de disk radius variabele die in de bovenste cel geïnitialiseerd wordt, wat gebeurt er als disk radius naar 0 gaat?
# 2. Wat betekent gridstep en wat voor impact heeft deze variabele op de simulatie?
# 3. Pak uit de tweede code cel in opdracht 2 een andere variabelen en onderzoek wat deze variabele doet en wat voor impact die heeft op de simulatie.

# %% [markdown]
# ##### Antwoorden 2a
#
# 1. disk_radius is de straal van de schijf. Als disk_radius naar 0 gaat, zal de schijf steeds kleiner worden en uiteindelijk als een puntlading gedragen. disk_radius bepaalt ook welk deel van het rooster van punten een lading krijgen.
# 2. grid_step bepaalt de afstand tussen de punten in het rooster. hoe kleiner grid_step, hoe nauwkeuriger de simulatie, vooral op plekken waar het veld sterk varieert, maar ook hoe langer het duurt om te runnen.
# 3. calculate_V_disk_at_origin_uniform_surface_charge_density, deze functie berekent het potentiaal in het midden van de schijf, en gebruikt daarvoor de formule voor een uniform geladen schijf. Hij doet dit door de schijf op te delen in puntladingen. Voor elk punt dat binnen de schijf valt, wordt de bijdrage aan het elektrisch potentiaal op elk punt in het totale domein berekend en opgeteld. Hierbij wordt de hulpfunctie electric_potential_point_charge_cartesian aangeroepen.

# %% [markdown]
# #### Vraag 2b Oppervlakte lading
#
# Pas de cel die je in vraag 2a hebt aangepast weer aan naar de originele waardes. Run hierna alle code cellen na vraag 2 weer opnieuw.
# Het aantal punten dat gebruikt wordt om de schijf te creëren is number_point_charges_on_disk en de lading van een punt is charge_one_point in Coulomb.
# 1. Bereken en print de ladingsdichtheid $\sigma$ met een correcte eenheid.

# %%
###
###Hier jouw code###
###

A=np.pi*disk_radius**2
totalcharge = number_point_charges_on_disk * charge_one_point
sigma = totalcharge / A
print("De oppervlakte ladingsdichtheid sigma is:", sigma, "C/m^2")
# Out:
# De oppervlakte ladingsdichtheid sigma is: 9.948952331500036e-13 C/m^2

# %% [markdown]
# ##### Vraag 2c
#
# 1. Plot het elektrische potentiaal langs de $r$ as ($z = 0$ m).
# 2. Plot het potentiaal op de rand van de schijf in hetzelfde figuur $V = \sigma R/(\pi \epsilon_0)$
# (bekijk probleem 2.51 in het Griffiths' boek)
# 3. Plot het potentiaal in het centrum van de schijf in hetzelfde figuur $V = \sigma R/(2 \epsilon_0)$

# %%
# Vul deze code aan zodat deze vraag 2.3 beantwoord.
idx_z_zero = find_idx_nearest(z,0)

V_0 = (sigma*disk_radius)/(2*epsilon0) # potentiaal op r = 0
V1=V[idx_z_zero,:]
V_R = (sigma*disk_radius)/(np.pi*epsilon0) # potentiaal op de straal van de schijf
r_R = disk_radius # straal van de schijf

plt.title(f"Potentiaal van een uniform geladen schijf op verschillende afstanden van het midden van de schijf")
plt.plot(r, V1, "o-", label="numeriek potentiaal")
plt.plot(0, V_0, "c.", label="theoretisch potentiaal $r$=0 m")
plt.plot(r_R, V_R, "c.", label="theoretisch potentiaal $r$=$R$ m")
plt.legend()
plt.xlabel("Straal (m)")
plt.ylabel("Potentiaal (V)")
# Out:
# Text(0, 0.5, 'Potentiaal (V)')

# %% [markdown]
# #### Vraag 2d
#
# Het theoretische potentiaal op de as van een hele grote schijf ($R>>z$) is:
# $V(z, r=0) = \frac{\sigma}{2\epsilon_0} \big( R - |z|\big)$
# zie probleem 2.26 in het Griffiths boek.
# 1. Plot het numeriek berekend elektrische potentiaal op de $z$-as ($r=0$).
# 2. Plot het theoretische component van het potentiaal op de as van een schijf met ladingsdichtheid $\sigma$.
# 3. Sla deze plot op.

# %%
###
###Hier jouw code###
###
idx_r_zero = find_idx_nearest(r,0)
V2=V[:,idx_r_zero]
V_Z = sigma/(2*epsilon0)*(disk_radius - np.abs(z))

plt.figure()
plt.plot(z, V2, "o-", label="numeriek potentiaal $r=0$")
plt.plot(z, V_Z, "r-", label="theoretisch potentiaal")
plt.xlabel("Afstand van de schijf (m)")
plt.ylabel("Potentiaal (V)")
plt.title("Potentiaal van een uniform geladen schijf op verschillende afstanden van de schijf")
plt.legend()
plt.savefig("potentiaal_2d.png")
plt.show()

# %% [markdown]
# #### Vraag 2e
#
# Het theoretische elektrische veld van een oneindig geladen oppervlakte is $|E| = \sigma/(2 \epsilon_0)$ (zie Example 2.5 in het Griffith boek).
# 1. Plot het z-component van het numeriek berekende elektrische veld op de as van de schijf ($r=0$).
# 2. Plot het theoretische elektrische veld voor een oneindig geladen oppervlak.
# 3. Sla deze plot ook op.

# %%
###
###Hier jouw code###
###

idx_r_zero_E = find_idx_nearest(r_for_E,0)
print("De index bij r=0 voor E is:", idx_r_zero_E)
E2 = Ez[:,idx_r_zero_E]
E_Z = (sigma/(2*epsilon0))*np.sign(z_for_E)

plt.figure()
plt.plot(z_for_E, E2, "o-", label="Numeriek elektrisch veld $r=0$")
plt.plot(z_for_E, E_Z, "r-", label="Theoretisch elektrisch veld")
plt.xlabel("Afstand van de schijf (m)")
plt.ylabel("Elektrisch veld (V/m)")
plt.title("Elektrisch veld van een uniform geladen schijf op verschillende afstanden van de schijf")
plt.legend()
plt.savefig("elektrisch_veld_2d.png")
plt.show()
# Out:
# De index bij r=0 voor E is: 0

# %% [markdown]
# #### Vraag 2f
# 1. Waar benadert het elektrische veld van een uniform geladen schijf dat van een oneindig geladen plaat?
# 2. Beschrijf en verklaar de verschillen die je opvallen in de plot die je bij vraag 2e hebt gemaakt.

# %% [markdown]
# ##### Antwoorden 2f
#
# 1. Het elektrisch veld van een uniform geladen schijf benadert dat van een oneindig geladen plaat als we
# heel dicht bij de schijf zijn, dus als $z$ heel klein is. Hoe verder we zitten hoe meer het veld afwijkt.
# 2. Een verschil is dat bij hogere z de uniform geladen schijf asymptotisch naar 0 gaat, terwijl dat van de oneindige plaat constant lijkt. Verklaring zou kunnen zijn dat bij hogere z de randen van de schijf zichtbaar worden en daar het veld niet recht omhoog wijst maar ook naar buiten. Op hele grote z lijkt de schijf ook meer op een puntlading.
# Ander punt is dat de pieken van de blauwe curve niet de pieken van de rode lijn halen. Dit kan komen doordat de simulatie niet helemaal nauwkeurig is, bijvoorbeeld doordat er eindige stappen en puntladingen zijn gebruikt in plaats van een continu oppervlak of tijd.

# %% [markdown]
# #### Vraag 2g
#
# 1. Pas helemaal bovenaan in vraag 2 de straal van de schijf aan.
# 2. Voer dan vragen 2d en 2e opnieuw uit.
# 3. Voeg de opgeslagen figuren hieronder toe.
# 4. Beschrijf de verschillen tussen de twee verschillende stralen.

# %%
###
###Jouw code hier###
###
#display(Image("folder-name/image-name"))
disk_radius = 1
idx_r_zero = find_idx_nearest(r,0)
V3=V[:,idx_r_zero]
V_Z = (sigma/(2*epsilon0))*(disk_radius - np.abs(z))

plt.figure()
plt.plot(z, V3, "o-", label="numeriek potentiaal $r=0$")
plt.plot(z, V_Z, "r-", label="theoretisch potentiaal")
plt.xlabel("Afstand van de schijf (m)")
plt.ylabel("Potentiaal (V)")
plt.title("Potentiaal van een uniform geladen schijf op verschillende afstanden van de schijf")
plt.legend()
plt.savefig("potentiaal_dif_R.png")
plt.show()

idx_r_zero_E = find_idx_nearest(r_for_E,0)
print("De index bij r=0 voor E is:", idx_r_zero_E)
E3 = Ez[:,idx_r_zero_E]
E_Z = (sigma/(2*epsilon0))*np.sign(z_for_E)

plt.figure()
plt.plot(z_for_E, E2, "o-", label="Numeriek elektrisch veld $r=0$")
plt.plot(z_for_E, E_Z, "r-", label="Theoretisch elektrisch veld")
plt.xlabel("Afstand van de schijf (m)")
plt.ylabel("Elektrisch veld (V/m)")
plt.title("Elektrisch veld van een uniform geladen schijf op verschillende afstanden van de schijf")
plt.legend()
plt.savefig("elektrisch_veld_dif_R.png")
plt.show()
# Out:
# De index bij r=0 voor E is: 0

# %% [markdown]
# ##### Antwoorden 2g
#
# Bij het elektrisch veld lijken er geen verschillen te zijn tussen de stralen. Dit is omdat R niet voorkomt in de formule voor het elektrisch veld van een oneindig oppervlak. Bij de potentiaal ligt de theoretische lijn voor de grotere schijf lager dan de numeriek potentiaal. Bij de formule voor het potentiaal komt R wel voor. Doordat ik de straal kleiner heb gemaakt, wordt het potentiaal kleiner. Doordat de formule het nulpunt legt bij z=R, ligt de theoretische lijn lager.

# %% [markdown]
# #### Vraag 2h
# Het elektrische veld een afstand $z$ boven het midden van een uniform geladen schijf met een straal $R$ en oppervlakte lading $\sigma$ wordt gegeven door:
# $$ \mathbf{E} = \frac{\sigma}{2\epsilon_0} \bigg[ 1- \frac{z}{\sqrt{R^2 + z^2}}\bigg] \hat{\mathbf{z}}$$
# Zie probleem 2.6 in het boek van Griffith.
#
# 1. Wat moet de hoogte $z$ zijn boven de schijf zodat het elektrische veld door de schijf 10% is in vergelijking met dat van een oneindig geladen plaat?
#
# Voeg hieronder je analytische uitwerking toe.

# %% [markdown]
# ##### Antwoord 2h
#
# sigma/(2*epsilon0)*(1-z/sqrt(R**2+z**2))=0.10*sigma/(2*epsilon0);
# 1-z/sqrt(R**2+z**2)=0.10;
# 0.9=z/sqrt(R**2+z**2);
# 0.81 = z**2/(R**2+z**2);
# 0.81*R**2=z**2-0.81*z**2;
# 0.81*R**2=0.19*z**2;
# z=sqrt(0.81/0.19)*R;
# z=2.065*R;
#
# De hoogte moet ongeveer 2.605 keer de straal zijn om het veld 10% te maken van dat van een oneindig geladen plaat.

# %% [markdown]
# ### 3) Een geladen schijf op een constant potentiaal
#
# We zullen nu het verschil bestuderen tussen een uniform geladen schijf en een geleidende schijf die op een bepaald potentiaal gehouden wordt.
# De code hieronder lost numeriek de laplace vergelijking op voor een geleidende schijf op een constant potentiaal. Hieruit volgt het potentiaal in de ruimte.

# %%
# Run deze cel pas deze niet aan.
disk_radius = 3  # (m)  
V0 = 0  # electric potential at boundary of domain (V)

# Één schijf
z_pos_disk1 = 0  # z-coördinaat van de eerste geleidende schijf (m)
z_pos_disk2 = z_pos_disk1  # z-coördinaat van de tweede geleidende schijf (m)
V1 = 10  # elektrische potentiaal van de eerste geleidende schijf (V)

r, z, r_repmat, V, B, idx_R, idx_z1, idx_z2 = initialize_variables_Laplace(width_domain, disk_radius, height_domain, grid_step, z_pos_disk1, z_pos_disk2, V0, V1, V1)

"""--------------------------------------------------------------------
Veldberekening voor een geleidende schijf
"""
solve_Laplace_equation(V, B, r_repmat, grid_step, idx_z1, idx_z2, idx_R, V1, V1, 1e-3)
Er, Ez, normE = compute_E_disk(V,B,grid_step)
r_for_E = r[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de r-dimensie
z_for_E = z[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de z-dimensie

""""---------------------------------------------------------
Plot het berekende veld
"""
plot_results_disk(Ez, Er, normE, V, r, z, grid_step, disk_radius, z_pos_disk1, z_pos_disk2)

# %% [markdown]
# #### Vraag 3a: De simulatie van het elektrische veld van een geleidende schijf op constant potentiaal
#
# 1. Plot de elektrische veld sterkte op de as van de schijf.
# 2. Print de norm van het elektrische veld op de as heel dicht bij het midden van de schijf, zorg hier voor een nette opmaak.

# %%
###
###Jouw code hier###
###

idx_r0 = find_idx_nearest(r_for_E,0)
print("De index bij r=0 voor E is:", idx_r0)
E4 = Ez[:,idx_r0]

plt.figure()
plt.plot(z_for_E, E4, "o-", label="Numerieke veldsterkte $r=0$")
plt.xlabel("Afstand van de schijf (m)")
plt.ylabel("Elektrisch veld (V/m)")
plt.title("Elektrisch veld van een geleidende schijf op verschillende afstanden van de schijf")
plt.legend()
plt.show()

idx_z0 = find_idx_nearest(z_for_E,0)
E_bij_midden = normE[idx_z0, idx_r0]
print("De veldsterkte bij het midden van de schijf is:", E_bij_midden, "V/m")
# Out:
# De index bij r=0 voor E is: 0
# De veldsterkte bij het midden van de schijf is: 1.5214455446610486e-05 V/m

# %% [markdown]
# #### Vraag 3b: De oppervlakte lading in het midden van een geleidende schijf op constant potentiaal
#
# 1. Met welke formule kan je de oppervlaktelading benaderen in het midden van de schijf($r=0$, $z=0$)?
# 2. Print netjes de benadering van de oppervlakte lading in het midden van de schijf.

# %% [markdown]
# ##### Antwoord 3b
#
# Voor de oppervlaktelading in het midden van de schijf kun je de wet van Gauss gebruiken. Gaussian surface is een pillendoosje dat door de schijf gaat in het midden. De flux wordt dan E*A. De rechterkant wordt dan Q_enc/epsilon_0=sigma*A/epsilon_0. Hieruit wordt de wet van gauss, sigma = epsilon_0*E.

# %%
#### Print met deze cel met een nette opmaak je antwoord op vraag 3b 2.
sigma_antwoord = E_bij_midden * epsilon0
print(f"De oppervlakte ladingsdichtheid sigma bij het midden van de schijf is: {sigma_antwoord:.2e} C/m^2")
# Out:
# De oppervlakte ladingsdichtheid sigma bij het midden van de schijf is: 1.35e-16 C/m^2

# %% [markdown]
# #### Vraag 3c: De oppervlaktelading van een geleidende schijf op constant potentiaal
#
# De oppervlakte lading $\sigma(r)$ van een geleidende schijf met straal $R$ is niet uniform verdeeld over de schijf, maar wordt gegeven door (Problems 2.58 and 2.63 Griffiths 5th edition):
# $$\sigma(r) = \frac{Q}{2 \pi R \sqrt{R^2 - r^2}}$$
#
# 1. Bereken de totale lading op de schijf met behulp van vraag 3a en 3b.
# 2. Vergelijk de oppervlakte lading in het centrum van de geleidende schijf met dat van een uniform geladen schijf met dezelfde totale lading.
# 3. Plot de oppervlakte lading van de geleidende schijf met de berekende lading $Q$, tussen $r = 0$ en $R$.
# 4. Plot in hetzelfde figuur de oppervlaktelading van een uniform geladen schijf met dezelfde lading $Q$.

# %%
###
###Jouw code hier###
###

# r=0 bij het midden
Q=sigma_antwoord*(2*np.pi*disk_radius**2)
print("De totale lading op de schijf is:", Q, "C")

# een uniform geladen schijf heeft een oppervlakte lading van sigma = Q/A
A_uniform = np.pi*disk_radius**2
sigma_uniform = Q / A_uniform
print("De oppervlakte ladingsdichtheden staan hier. Eerst die van uniforme schijf en daarna die van de geleidende schijf:")
print(sigma_uniform,"C/m^2",sigma_antwoord,"C/m^2")
def function(r,R,Q):
    return Q/(2*np.pi*R*np.sqrt(R**2-r**2))


r_try = np.linspace(0, disk_radius, 100)
sigma_geleidend = function(r_try, disk_radius, Q)

plt.figure()
plt.plot(r_try, sigma_geleidend,'.', label="Oppervlakte ladingsdichtheid van de geleidende schijf")
plt.axhline(y=sigma_uniform, label="Oppervlakte ladingsdichtheid van de uniforme schijf", color='red',linestyle='--')
plt.title("Ladingsverdeling op een schijf")
plt.xlabel("Straal (m)")
plt.ylabel("Oppervlakte ladingsdichtheid (C/m^2)")
plt.legend()
plt.show()
# Out:
# De totale lading op de schijf is: 7.617602527233986e-15 C
# De oppervlakte ladingsdichtheden staan hier. Eerst die van uniforme schijf en daarna die van de geleidende schijf:
# 2.694175770485785e-16 C/m^2 1.3470878852428924e-16 C/m^2
# /var/folders/pb/ck_h157s50jdw0k3wg0pz4qw0000gn/T/ipykernel_42438/1423025615.py:15: RuntimeWarning: divide by zero encountered in divide
#   return Q/(2*np.pi*R*np.sqrt(R**2-r**2))

# %% [markdown]
# #### Vraag 3d: Het edge effect
#
# 1. Bepaal het maximum elektrische veld door de geleidende schijf in de simulatie.
# 2. Bepaal waar in de ruimte dit maximum zich bevindt.
# 3. Hoeveel hoger is dit maximum dan het elektrische veld in het midden van de schijf?
# 4. Print met een nette opmaak de waardes die je hier hebt berekend.
# 5. Leg uit wat de oorzaak van dit lokaal hoge elektrische veld is?

# %%
# Deze cel kan je gebruiken om van vraag 3c 1 tot en met 4 te beantwoorden.
E_max = np.max(normE)
indexen = np.where(normE == E_max)
idx_z_max = indexen[0][0]
idx_r_max = indexen[1][0]
z_max=z_for_E[idx_z_max]
r_max=r_for_E[idx_r_max]
factor = E_max / E_bij_midden

print("De maximale veldsterkte is:", E_max, "V/m")
print("Het maximum bevindt zich op z=",z_max,"m en r=",r_max,"m.")
print("Het maximum veld is", factor, "keer groter dan het veld bij het midden van de schijf.")
# Out:
# De maximale veldsterkte is: 11.752993215742134 V/m
# Het maximum bevindt zich op z= 0.09999999999998188 m en r= 3.0 m.
# Het maximum veld is 772488.5886967775 keer groter dan het veld bij het midden van de schijf.

# %% [markdown]
# ##### Antwoord 3d.5
#
# Het maximum bevindt op r=1. Dat is ook de straal van de schijf. Daar zijn dus veel ladingen bij elkaar en zorgen voor een hoger veld. Het kan komen doordat gelijke ladingen elkaar afstoten en daardoor naar de rand bewegen om zo ver mogelijk van elkaar te zijn.

# %% [markdown]
# ### 4) Twee geleidende platen op potentiaal $V_1$ and $-V_1$
#
# In de cel hieronder wordt weer op dezelfde manier als in opdracht 3 de laplace vergelijking van deze situatie opgelost.

# %%
# Run deze cel en pas de cel aan in vraag 4f.
# Voor twee schijven
spacing_between_disks = 2  # (m)
z_pos_disk1 = spacing_between_disks/2  # z-coördinaat van de eerste geleidende schijf (m)
z_pos_disk2 = -spacing_between_disks/2  # z-coördinaat van de tweede geleidende schijf (m)
V1 = 10  # elektrische potentiaal van de eerste geleidende schijf (V)
V2 = -10  # elektrische potentiaal van de tweede geleidende schijf (V)

r, z, r_repmat, V, B, idx_R, idx_z1, idx_z2 = initialize_variables_Laplace(width_domain, disk_radius, height_domain, grid_step, z_pos_disk1, z_pos_disk2, V0, V1, V2)

"""--------------------------------------------------------------------
Veldberekening voor de twee geleidende schijven
"""
solve_Laplace_equation(V, B, r_repmat, grid_step, idx_z1, idx_z2, idx_R, V1, V2, 1e-3)
Er, Ez, normE = compute_E_disk(V, B, grid_step)
r_for_E = r[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de r-dimensie
z_for_E = z[1:-1]  # de centered finite-difference method kan E niet berekenen op het allereerste en allerlaatste gridpunt in de z-dimensie

""""---------------------------------------------------------
Plot het berekende veld
"""
plot_results_disk(Ez, Er, normE, V, r, z, grid_step, disk_radius, z_pos_disk1, z_pos_disk2)

# %% [markdown]
# #### Vraag 4a: Het $z$-component van het numeriek berekende elektrische veld van twee geleidende platen
#
# 1. Plot het $z$-component van het numeriek berekende elektrische veld op de as van de schijven.

# %%
###
###your code here###
###
idx_r_double = find_idx_nearest(r_for_E,0)

print("De index bij r=0 voor E is:", idx_r_double)

E_double = Ez[:, idx_r_double]

plt.figure()
plt.plot(z_for_E, E_double, "o-", label="Numerieke veldsterkte")
plt.xlabel("Afstand van de schijven (m)")
plt.ylabel("Elektrisch veld (V/m)")
plt.title("Elektrisch veld tussen twee schijven")
plt.legend()
plt.show()
# Out:
# De index bij r=0 voor E is: 0

# %% [markdown]
# #### Vraag 4b: Verschillen tussen verschillende configuraties
#
# 1. Gegeven het potentiaal tussen twee geleidende platen, wat is het theoretische elektrische veld in elke regio? Laat dit zien met een afleiding en een schets die de verschillende regio's aangeeft.
# 2. Beschrijf het numeriek berekende elektrische veld op de as van de schijven, komt dit overeen met het theoretische elektrische veld?
# 3. Vergelijk het numeriek berekende elektrische veld tussen de twee schijven ($r=0$ and $z=0$) met dat van een enkele geleidende schijf op hetzelfde potentiaal(vraag 3a), welk voordeel heeft deze configuratie?

# %% [markdown]
# ##### Antwoorden 4b
#
# 1. Het theoretische elektrische veld tussen de platen is uniform zoals in de afbeelding te zien is, dit is zone 2. In zone 1 en 3 cancelen de velden van de platen elkaar uit en is het veld daar 0. Het veld in zone 2 is te bepalen door de laplace vergelijking op te lossen met de algemene oplossing Ax + B en de randvoorwaarden V(0)=V1 en V(d)=-V1. V(x) = -2*V1/d*x + V1, E = -dV/dx = 2*V1/d.
# Zie de afleiding hieronder: ![Schets](Fig.jpeg)
# 2. Ja dit komt overeen. Zone 1 en 3 stellen de rechterkant en linkerkant van de afbeelding voor, waar het veld 0 nadert. En zone 2 stelt het midden voor, waar het veld constant is.
# 3. De configuratie van twee platen heeft als voordeel dat het veld tussen de platen uniformer is dan bij een enkele schijf. Bij een enkele schijf heb je ook een edge effect waardoor het veld bij de rand hoger is dan in het midden. Dat is bij de platen niet zo. Voordeel bij de twee platen is dat het veld beter te regelen is.

# %% [markdown]
# #### Vraag 4c: De capaciteit tussen twee geleidende platen
#
# 1. Bepaal de verwachte oppervlakte lading op de binnenzijde van een van de schijven.
# 2. Bepaal de verwachte totale lading op beide schijven.
# 3. Bepaal de capaciteit van deze situatie.
# 4. Print alle bepaalde waardes op een nette en overzichtelijke manier.

# %%
###
###your code here###
###
#E_binnen = (V1-V2)/spacing_between_disks
#E*A=sigma*A/epsilon0
sigma_binnen = epsilon0 * 2*V1/spacing_between_disks
print("De oppervlakte ladingsdichtheid sigma op de binnenkant van de schijven is:", sigma_binnen, "C/m^2")

#A = np.pi*disk_radius**2
Q_1 = sigma_binnen * np.pi*disk_radius**2*2
print("De lading op beide schijven is:", Q_1, "C")

C=Q_1/(V1-V2)
print("De capaciteit van de condensator is:", C, "F")
# Out:
# De oppervlakte ladingsdichtheid sigma op de binnenkant van de schijven is: 8.853999999999999e-11 C/m^2
# De lading op beide schijven is: 5.006819043879125e-09 C
# De capaciteit van de condensator is: 2.5034095219395624e-10 F

# %% [markdown]
# #### Vraag 4d: Theoretische oppervlakte lading
#
# 1. Is de oppervlaktelading aan de buitenkant van de schijven gelijk aan nul, beargumenteer waarom wel of niet.
# 2. Wat is het elektrische veld nabij het oppervlak van een geleider?

# %% [markdown]
# ##### Antwoorden 4d
#
# 1. Nee, bij oneindige platen zou het wel 0 zijn, maar bij deze platen niet. Door het edge effect is er ook lading aan de buitenkant van de schijven, de veldlijnen buigen ook naar buiten, en daardoor is er ook een oppervlakte lading aan de buitenkant.
# 2. Het elektrische veld nabij het oppervlak van een geleider is loodrecht op het oppervlak en heeft een sterkte die gelijk is aan $\sigma/\epsilon_0$.

# %% [markdown]
# #### Vraag 4e: Numeriek berekende ladingsdichtheid
#
# 1. Welke waarde heeft het $z$-component van het elektrische veld, op de as van de schijf net onder de onderste schijf.
# 2. Wat is volgens de formule uit vraag 4d 2 de ladingsdichtheid aan de onderkant van de onderste geleidende plaat.
# 3. Welke waarde heeft het $z$-component van het elektrische veld, op de as van de schijf net boven de onderste schijf.
# 4. Wat is volgens de formule uit vraag 4d 2 de ladingsdichtheid aan de bovenkant van de onderste geleidende plaat.
# 5. Print de bepaalde waardes op een nette en overzichtelijke manier.

# %%
###
###Your code here###
###
#veld net onder is idx_z2-1 en op de as betekent r=0
E_onder = Ez[idx_z2-1, idx_r_double]
print("De veldsterkte net onder de onderste schijf is:", E_onder, "V/m")
sigma_onder = epsilon0 * np.abs(E_onder)
print("De oppervlakte ladingsdichtheid sigma net onder de onderste schijf is:", sigma_onder, "C/m^2")
E_boven = Ez[idx_z2+1, idx_r_double]
print("De veldsterkte net boven de onderste schijf is:", E_boven, "V/m")
sigma_boven = epsilon0 * np.abs(E_boven)
print("De oppervlakte ladingsdichtheid sigma net boven de onderste schijf is:", sigma_boven, "C/m^2")
# Out:
# De veldsterkte net onder de onderste schijf is: -2.810041058977788 V/m
# De oppervlakte ladingsdichtheid sigma net onder de onderste schijf is: 2.4880103536189333e-11 C/m^2
# De veldsterkte net boven de onderste schijf is: -10.003416952350426 V/m
# De oppervlakte ladingsdichtheid sigma net boven de onderste schijf is: 8.857025369611066e-11 C/m^2

# %% [markdown]
# #### Vraag 4f: Conclusies over de ladingsdichtheid op de twee schijven
#
# 1. Wat kan je uit vraag 4d en e concluderen over de daadwerkelijke lading op een schijf in tegenstelling tot de berekende lading in vraag 4c?
# 2. Wat is de invloed hiervan op de capaciteit berekend in vraag 4c?
# 3. Run de cel net onder het kopje vraag 4 opnieuw, maar dan met een kleinere afstand tussen de schijven, wat verandert er?

# %% [markdown]
# ##### Antwoorden 4f
#
# 1. Er is niet alleen lading aan de binnenkant van de schijven, maar ook aan de buitenkant. De totale lading op de schijf is dus groter dan alleen die aan de binnenkant.
# 2. De capaciteit is groter dan berekend in 4c, omdat er meer lading op de schijven zit dan alleen die aan de binnenkant.
# 3. Als de afstand tussen de schijven kleiner wordt, wordt het elektrisch veld groter. Ook lijkt het idealer te worden, en een groter deel van de lading zit aan de binnenkant van de schijven.

# %% [markdown]
# ### 5) Voorbereidende opdracht voor de fysieke DEF ontwerpopdracht
#
# In deze vraag zullen we ingaan op benodigde voorkennis voor de fysieke ontwerpopdracht "Maak een sensor met condensatoren". De formules die je in deze opdracht opstelt, heb je nodig gedurende de fysieke ontwerpopdracht.
#
# In deze vraag zullen we kijken naar de ideale vlakke plaat condensator. Als de afstand tussen de platen veel kleiner is dan de grootte van de platen dan wordt de aanname gemaakt dat het veld tussen de platen constant is. Deze aanname zal niet helemaal overeenkomen met de werkelijkheid, zoals je in deze opdracht en de fysieke DEF ontwerpopdracht achter zal komen.

# %% [markdown]
# #### Vraag 5a: Functies voor de capaciteit van enkele opdrachten
#
# 1. Vind de formule voor de capaciteit van een vlakke plaat condensator en een cilinder condensator, onder de aanname dat de afstand tussen de platen veel kleiner is dan het oppervlakte van de condensator (vlakke plaat aanname).
# 2. Schrijf een python functie die de relevante parameters als input neemt en de capaciteit van een vlakke plaat condensator als output heeft.
# 3. Vind de formule voor de capaciteit van een cilinder condensator onder de aanname dat de afstand tussen de binnen en buiten wand klein is.
# 4. Schrijf een python functie die de relevante parameters als input neemt en de capaciteit van een cilinder condensator als output heeft.

# %%
import numpy as np
relevante_parameters = {
    "A": 1,  # oppervlakte van de platen (m^2)
    "d": 0.01,  # afstand tussen de platen (m)
    "L": 1,  # lengte van de cilinder (m)
    "R1": 0.01,  # binnenstraal van de cilinder (m)
    "R2": 0.02,  # buitenstraal van de cilinder (m)
}
epsilon0 = 8.854e-12  # permittiviteit van vacuum (F/m)

def vlakkeplaat(relevante_parameters):
    C = epsilon0 * relevante_parameters["A"] / relevante_parameters["d"]
    return C

def cilinder(relevante_parameters):
    C = 2 * np.pi * epsilon0 * relevante_parameters["L"] / np.log(relevante_parameters["R2"] / relevante_parameters["R1"])
    return  C

# %%
import numpy as np
relevante_parameters = {
    "A": 1,  # oppervlakte van de platen (m^2)
    "d": 0.01,  # afstand tussen de platen (m)
    "L": 1,  # lengte van de cilinder (m)
    "R1": 0.01,  # binnenstraal van de cilinder (m)
    "R2": 0.02,  # buitenstraal van de cilinder (m)
}
epsilon0 = 8.854e-12  # permittiviteit van vacuum (F/m)

def vlakkeplaat(relevante_parameters):
    C = epsilon0 * relevante_parameters["A"] / relevante_parameters["d"]
    return C

def cilinder(relevante_parameters):
    C = 2 * np.pi * epsilon0 * relevante_parameters["L"] / np.log(relevante_parameters["R2"] / relevante_parameters["R1"])
    return  C

#4. Capaciteit van de condensatoren als ze gevuld zijn met water (die een relatieve permittiviteit van ongeveer 80 heeft):
epsilon_water = 80 * epsilon0  # relatieve permittiviteit van water

def vlakkeplaat_water(relevante_parameters):
    C = epsilon_water * relevante_parameters["A"] / relevante_parameters["d"]
    return C

def cilinder_water(relevante_parameters):
    C = 2 * np.pi * epsilon_water * relevante_parameters["L"] / np.log(relevante_parameters["R2"] / relevante_parameters["R1"])
    return  C
print("Capaciteit van de vlakke plaat condensator in vacuum:", vlakkeplaat(relevante_parameters), "F")
print("Capaciteit van de cilinder condensator in vacuum:", cilinder(relevante_parameters), "F")
print("Capaciteit van de vlakke plaat condensator in water:", vlakkeplaat_water(relevante_parameters), "F")
print("Capaciteit van de cilinder condensator in water:", cilinder_water(relevante_parameters), "F")
# Out:
# Capaciteit van de vlakke plaat condensator in vacuum: 8.853999999999999e-10 F
# Capaciteit van de cilinder condensator in vacuum: 8.025903339147594e-11 F
# Capaciteit van de vlakke plaat condensator in water: 7.083199999999998e-08 F
# Capaciteit van de cilinder condensator in water: 6.420722671318075e-09 F

# %% [markdown]
# #### Vraag 5b: Capaciteit van enkele simpele condensatoren
#
# Gebruik in deze opdracht de functie die je bij vraag 5.1 geschreven hebt.
# Hieronder staan een aantal condensatoren waarvoor jullie de capaciteit gaan berekenen. Print de capaciteit van elke condensator op een nette en overzichtelijke manier.
# 1. Bereken de capaciteit van een condensator gemaakt van twee vierkante plaatjes van 10 bij 10 cm met een plaatafstand van 1 mm en lucht als medium?
# 2. Bereken de capaciteit van een cilinder condensator met een binnendiameter van 9 mm en een buitendiameter van 10 mm met een lengte van 10 cm en lucht als medium?
# 3. Bereken de capaciteit van de condensatoren als de afstand tussen de platen verdubbeld
# 4. Bereken de capaciteit van de condensatoren uit 1 en 2 hierboven beschreven als ze gevuld zijn met water.
# 5. Bereken de capaciteit van de condensatoren uit 1 en 2 hierboven als de holte gevuld is met PVC.

# %%
import numpy as np

def vlakkeplaat(relevante_parameters):
    C = epsilon0 * relevante_parameters["A"] / relevante_parameters["d"]
    return C

def cilinder(relevante_parameters):
    C = 2 * np.pi * epsilon0 * relevante_parameters["L"] / np.log(relevante_parameters["R2"] / relevante_parameters["R1"])
    return  C

epsilon0 = 8.854e-12  # permittiviteit van vacuum (F/m)

#1. Capaciteit van een condensator met twee vierkante platen van 10 cm bij 10 cm, gescheiden door een afstand van 1 mm:
relevante_parameters = {
    "A": 0.01,  # oppervlakte van de platen (m^2)
    "d": 0.001,  # afstand tussen de platen (m)
#    "L": 1,  # lengte van de cilinder (m)
#    "R1": 0.01,  # binnenstraal van de cilinder (m)
#    "R2": 0.02,  # buitenstraal van de cilinder (m)
}

print(f"1. De capaciteit van de vlakke plaat condensator is {vlakkeplaat(relevante_parameters)} F")

#2. Capaciteit van een cilinder condensator met een lengte van 10cm , een binnendiameter van 9mm en een buitendiameter van 10mm:
relevante_parameters_cilinder = {
    "L": 0.1,  # lengte van de cilinder (m)
    "R1": 0.0045,  # binnenstraal van de cilinder (m)
    "R2": 0.005,  # buitenstraal van de cilinder (m)
}
print(f"2. De capaciteit van de cilinder condensator is {cilinder(relevante_parameters_cilinder)} F")

#3. Verdubbeling van de afstand tussen de platen:
relevante_parameters["d"] = 0.002  # afstand tussen de platen (m)
print(f"3. De capaciteit van de vlakke plaat condensator is {vlakkeplaat(relevante_parameters)} F")

#4. Capaciteit van de condensatoren als ze gevuld zijn met water (die een relatieve permittiviteit van ongeveer 80 heeft):
epsilon_water = epsilon0 * 80  # permittiviteit van water (F/m)
def vlakkeplaat_water(relevante_parameters):
    C = epsilon_water * relevante_parameters["A"] / relevante_parameters["d"]
    return C
def cilinder_water(relevante_parameters):
    C = 2 * np.pi * epsilon_water * relevante_parameters["L"] / np.log(relevante_parameters["R2"] / relevante_parameters["R1"])
    return  C
print(f"4. De capaciteit van de vlakke plaat condensator gevuld met water is {vlakkeplaat_water(relevante_parameters)} F")
print(f"De capaciteit van de cilinder condensator gevuld met water is {cilinder_water(relevante_parameters_cilinder)} F")

#5. Capaciteit van de condesnsatoren als de holte gevuld is met pvc (die een relatieve permittiviteit van ongeveer 3 heeft):
epsilon_pvc = epsilon0 * 3  # permittiviteit van pvc (F/m
def vlakkeplaat_pvc(relevante_parameters):
    C = epsilon_pvc * relevante_parameters["A"] / relevante_parameters["d"]
    return C
def cilinder_pvc(relevante_parameters):
    C = 2 * np.pi * epsilon_pvc * relevante_parameters["L"] / np.log(relevante_parameters["R2"] / relevante_parameters["R1"])
    return  C
print(f"5. De capaciteit van de vlakke plaat condensator gevuld met pvc is {vlakkeplaat_pvc(relevante_parameters)} F")
print(f"De capaciteit van de cilinder condensator gevuld met pvc is {cilinder_pvc(relevante_parameters_cilinder)} F")
# Out:
# 1. De capaciteit van de vlakke plaat condensator is 8.854e-11 F
# 2. De capaciteit van de cilinder condensator is 5.280092106841892e-11 F
# 3. De capaciteit van de vlakke plaat condensator is 4.427e-11 F
# 4. De capaciteit van de vlakke plaat condensator gevuld met water is 3.5415999999999994e-09 F
# De capaciteit van de cilinder condensator gevuld met water is 4.224073685473514e-09 F
# 5. De capaciteit van de vlakke plaat condensator gevuld met pvc is 1.3280999999999998e-10 F
# De capaciteit van de cilinder condensator gevuld met pvc is 1.5840276320525677e-10 F

# %% [markdown]
# #### Vraag 5c: Condensatoren uit het dagelijkse leven
#
# Gebruik in deze opdracht de functie die je bij vraag 5.1 geschreven hebt.
# Hieronder is een foto te zien van condensatoren die in het dagelijkse leven gebruikt wordt.
# Print de capaciteiten in deze vraag op een nette en overzichtelijke manier.
# 1. In figuur 5.1 is een condensator te zien van 1 $\micro$F, stel deze condensator kan geapproximeerd worden als een cilinder condensator met binnendiameter 5 mm en een buitendiameter van 6 mm. Bereken wat de lengte van de condensator dan zou zijn.
# Stel dat we een vierkante plaat condensator hebben van 1 $\micro$F.
# 2. Bereken hoe lang de vlakke plaat condensator moet zijn als er 0.5 mm tussen de platen zit en de platen 6 mm breed zijn.

# %% [markdown]
# ![figure 5.1](figures/Condensator_1_uF.jpg)

# %% [markdown]
# ##### Figure: 5.1 Een 1 microfarad condensator.

# %%
import numpy as np

#lengte bereken voor een cilinder condensator met een capaciteit van 1 microfarad, een binnendiameter van 5mm en een buitendiameter van 6mm:
epsilon0 = 8.854e-12  # permittiviteit van vacuum (F/m)
relevante_parameters_cilinder = {
    "R1": 0.0025,  # binnenstraal van de cilinder (m)
    "R2": 0.003,  # buitenstraal van de cilinder (m)
    "C": 0.000001,  # capaciteit in Farad
}
    
def cilinder(relevante_parameters_cilinder):
    R1 = relevante_parameters_cilinder["R1"]
    R2 = relevante_parameters_cilinder["R2"]
    C = relevante_parameters_cilinder["C"]
    L = C * np.log(R2 / R1) / (2 * np.pi * epsilon0)
    return L

print(f"De lengte van de cilinder condensator is {cilinder(relevante_parameters_cilinder)} m")

#lengte berekenen voor een vlakke plaat condensator met een capaciteit van 1 microfarad, een afstand tussen de platen van 0.5mm en de platen 6mm breed:

relevante_parameters_plaat = {
    "breedte": 0.006,   # 6 mm
    "d": 0.0005,        # 0.5 mm
    "C": 1e-6           # 1 microfarad
}
def vlakkeplaat(relevante_parameters_plaat):
    breedte = relevante_parameters_plaat["breedte"]
    d = relevante_parameters_plaat["d"]
    C = relevante_parameters_plaat["C"]

    L = C * d / (epsilon0 * breedte)
    return L
  
print(f"De lengte van de vlakke plaat condensator is {vlakkeplaat(relevante_parameters_plaat)} m")
# Out:
# De lengte van de cilinder condensator is 3277.3183867142097 m
# De lengte van de vlakke plaat condensator is 9411.941871847 m

# %% [markdown]
# #### Vraag 5d: Hoge capaciteit condensatoren
#
# 1. Beargumenteer of je antwoorden uit vraag 5c realistisch zijn.
# 2. Bekijk je formule uit vraag 5a en bedenk hoe ze dit binnen in de condensator opgelost hebben.

# %% [markdown]
# ##### Antwoorden 5d
#
# 1. Ze zijn realistisch. De reden dat de waardes zo enorm groot zijn is omdat de permitiviteitsconstante een hele kleine getal is.
# 2. In een condensator zouden ze verschillende materialen kunnen gebruiken waardoor de permetiviteit groter is. Ook kunnen ze dunne folie oprollen waardoor zij een oppervlak krijgen van breedte * uitgerolde lengte. Bij plaatcondensatoren kunnen de afstanden tussen de platen veel kleiner gemaakt worden.

# %% [markdown]
# #### Vraag 5e: Condensator in een achtbaan
#
# Gebruik in deze opdracht de functie die je bij vraag 5.1 geschreven hebt.
#
# Met het vak inleidend practicum zijn jullie naar Drievliet gegaan om daar metingen aan de attracties te doen. In Drievliet staat de achtbaan Formule X, deze achtbaan heeft een topsnelheid van 70 $\frac{\text{km}}{\text{h}}$ en bevat een treintje met plek voor 6 mensen. Deze snelheid bereikt de achtbaan door heel snel een karretje weg te schieten, dit wordt gedaan door de treintjes met een lineaire inductie motor te versnellen. Om de impact hiervan op het stroomnet te beperken gebruiken zij een condensator om de energie op te slaan en dan in een keer af te staan aan het treintje. In deze opdracht gaan we kijken wat de afmetingen zouden moeten zijn als ze vlakke plaat condensatoren zouden gebruiken.
#
# De energie die opgeslagen is in een condensator kan berekend worden met de onderstaande formule.
#
# $E = \frac{1}{2} CV^2$
# Hierin is $E$ de totaal opgeslagen energie $C$ de capaciteit en $V$ het voltage waarop de condensator opereert, in dit geval $10$ $kV$.
# 1. Schat de massa van een treintje dat afgeschoten wordt.
# 2. Bereken de totale energie van het treintje na het afschieten.
# 3. Bereken de totale capaciteit van de condensator.
# 4. Bereken het oppervlakte van een vlakke plaat condensator die deze capaciteit heeft als die gevuld is met water en de platen 1 mm van elkaar afstaan.
# 5. Print alle berekende waardes op een nette en overzichtelijke manier.
# 6. Is dit realistisch, bedenk een manier hoe dit toch kan in een relatief klein volume.

# %%
#1. massa schatting treintje:
gewicht_persoon = 70  # kg
gewicht_treintje = 500  # kg
aantal_personen = 6  # aantal personen in het treintje
totaal_gewicht = gewicht_treintje + (gewicht_persoon * aantal_personen)
print(f"1. Het totale gewicht van het treintje is {totaal_gewicht} kg")

#2. Energie van het treintje bij een snelheid van 70 km/h:
snelheid = 70 * 1000 / 3600  # omzetten van km/h naar m/s
energie = 0.5 * totaal_gewicht * snelheid**2
print(f"2. De kinetische energie van het treintje is {energie} J")

#3. Capaciteit van de condensator nodig om deze energie op te slaan bij een spanning van 10000 V:
spanning = 10000  # V
capaciteit = energie / (0.5 * spanning**2)
print(f"3. De benodigde capaciteit van de condensator is {capaciteit} F")

#4. Oppervlakte van een vlakke plaat condesator die deze capaciteit kan opslaan bij een afstand van 1 mm tussen de platen als hij met water is gevuld:
afstand = 0.001  # m
epsilon0_water = epsilon0 * 80  # permittiviteit van water (F/m)
oppervlakte = capaciteit * afstand / epsilon0_water
print(f"4. De benodigde oppervlakte van de platen is {oppervlakte} m^2")
# Out:
# 1. Het totale gewicht van het treintje is 920 kg
# 2. De kinetische energie van het treintje is 173919.75308641972 J
# 3. De benodigde capaciteit van de condensator is 0.0034783950617283945 F
# 4. De benodigde oppervlakte van de platen is 4910.767819246097 m^2

# %% [markdown]
# ##### Antwoorden 5e
#
# ##### Antwoorden 5e
#
# 6. Door een materiaal te gebruiken met een veel hogere relatieve permittatie en een veel kleinere afstand tussen de platen. Hierdoor kunnen de platen een veel kleiner oppervlak hebben.

# %% [markdown]
# #### Vraag 5f: Veranderende capaciteit
#
# Gebruik in deze opdracht de functie die je bij vraag 5.1 geschreven hebt.
#
# 1. Bereken en plot de capaciteit van een vlakke plaat condensator van $10$ bij $10$ $cm$ waarbij de afstand tussen de platen lineair toeneemt van $0.5$ $mm$ tot $5$ $mm$.
# 2. Bereken en plot de capaciteit van een cilinder condensator met een binnendiameter van 9 mm en een buitendiameter van 10 mm en 10 cm lang, waarbij de binnencilinder er langzaam in 10 seconde uitgetrokken wordt.

# %%
#1. Bereken de capaciteit van een vlakke plaat condensator met twee vierkante platen van 10 cm bij 10 cm, waarbij de afstand tussen de platen lineair toeneemt van 0.5 mm tot 5 mm:
import matplotlib.pyplot as plt

epsilon0 = 8.854e-12  # F/m
lengte = 0.1  # m
breedte = 0.1  # m
oppervlakte = lengte * breedte  # m^2

afstand_min = 0.5e-3  # m
afstand_max = 5e-3   # m

def capaciteit(afstand):
    return epsilon0 * oppervlakte / afstand

afstand = np.linspace(afstand_min, afstand_max, 1000)

plt.figure()
plt.plot(afstand * 1e3, capaciteit(afstand))
plt.xlabel("Afstand tussen de platen (mm)")
plt.ylabel("Capaciteit (F)")
plt.xlim(0, afstand_max * 1e3)
plt.ylim(0, capaciteit(afstand_min) * 1.1)
plt.title("Capaciteit van een vlakke plaat condensator als functie van de afstand tussen de platen")
plt.grid()
plt.show()

# %% [markdown]
# ## Stop hier met werken tot na de fysieke ontwerpopdracht in week 3.

# %% [markdown]
# ### 6) Reflectie opdracht voor na de fysieke ontwerpopdracht
#
#
# Als het goed is, heeft ieder teamlid van deze simulatie-opdracht een andere opstelling ontworpen hebben tijdens de fysieke ontwerpopdracht. Kies in goed overleg voor deze opdracht een van jullie twee ontwerpen.
#
# Voeg hieronder eerst een foto in van je opstelling die je gekozen hebt.
#
# Jullie gaan in deze opdracht het verschil tussen jullie voorspelde verband en jullie uiteindelijke verkregen kalibratie grafiek proberen te verklaren. Er zijn hiervoor drie mogelijke paden die jullie kunnen kiezen om te onderzoeken, Kies deel a, b of c en werk die volledig uit voor jullie ontwerp. Let op je hoeft er maar een uit te werken.

# %% [markdown]
# Verander de tekst hieronder zodat deze naar jouw foto verwijst. Zorg dat de foto in de map figures staat!
# ![figure 5.1](figures/P5.jpeg)

# %% [markdown]
# #### Vraag 6a: Dunne laag niet meegerekende diëlektricum
# Deze vraag is goed om te kiezen als je in je ontwerp een kleine laag extra materiaal hebt en deze tijdens de ontwerpopdracht niet hebben meegenomen in je theoretisch kalibratie grafiek.
#
# 1. Maak een nieuwe schets van je opstelling waarbij je de dikte van het extra diëlektricum meeneemt.
# 2. Leid de analytische oplossing af van de capaciteit van de hierboven getekende situatie.
# 3. Programmeer de analytische oplossing in python.
# 4. Maak hierna een plot van het kalibratiegrafiek, oude en nieuwe analytische oplossing in een grafiek.
# 5. Beschrijf en verklaar de verschillen tussen de grafieken.

# %% [markdown]
# ##### Antwoorden 6a
#
# *Laat in deze cel je analytische oplossing met schets zien, dit mag met foto's of via LATEX.*

# %%
# Schrijf hier de code voor je oplossing. Gebruik hier je eerder gemaakte functies
# def condensator_extra_laag(#jouw variabelen): # Schrijf hier jouw functie
    ## je functie


### Maak hier je plot

# %% [markdown]
# ##### Antwoorden 6a
#
# *Beschrijf en verklaar je verschillen in deze markdown cel.*

# %% [markdown]
# #### Vraag 6b1: Lading op een condensator met het edge effect meegenomen
#
# In deze opdracht gaan we verder in op het Edge effect en de invloed daarvan op de praktische capaciteit. Deze opdracht bouwt voort op de vraag 4.3.
# Jullie hebben tijdens de ontwerpopdracht vierkante platen gebruikt in tegenstelling tot de ronde platen waarvoor de factoren in figure[label] zijn afgeleid. Er is onderzoek gedaan naar de factoren waarmee de praktische capaciteit vergeleken met de daadwerkelijke capaciteit verschilt dat onderzoek vind je hier: https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=311759. Zoek in het onderzoek tabel 1 en formules 22 en 36 op.
#
# 1. Vergelijk de factor waarmee de schijf(disk) condensator verschilt met die van de vierkante plaat, kunnen we de vierkante plaat factor benaderen met de factor voor een disk condensator? Vergelijk het procentuele verschil tussen de factoren van de circulaire en vierkante platen, met de onzekerheden die in de meting zitten.

# %% [markdown]
# ##### Antwoord 6b1
#
# Voor de aspect ratio geldt: b = d/w met d: de afstand tussen de twee platen en w: de breedte van de vierkante platen.
# In ons expirement waren de platen 10 x 10 cm en varieerde de afstand tussen de platen tussen 0.5mm en 15mm.
# Op een maximale afstand (15 mm): b = 15/100 = 0.15
# Op een minimale afstand (0.5 mm): b = 0.5/100 = 0.0005
# In de tabel uit de studie is af te lezen dat voor een waarde van b = 0.1 er een Disk Capacitance(C_dn) en Square Capacitance (C_sn) van respectievelijk 1.318 en 1.300 is. Voor b = 0.2 geeft dit C_dn = 1.580 en C_sn = 1.550.
# Interpolatie geeft voor b = 0.15: C_dn = 1.449 en C_sn = 1.425.
# Het percentuele verschil hier tussen is ongeveer 1.68%.
# met een d van 0.05 krijgen we een b van 0.005. Voor zo'n lage waarde van b zou ik zeggen dat je er vanuit kan gaan dat het verschil in de capaciteit van een discus en een vierkant te verwaarlozen is.
# Dus kunnen we de vierkante plaat factor benaderen met de factor voor een disk condensator? Onze range van d = 0.5 mm tot d = 15 mm geeft ons een verschil in capaciteit tussen een ronde plaat en een vierkante plaat van ongeveer 0% tot 1.68%. Voor zulke kleine verschillen zou je kunnen zeggen dat we de capaciteit van een vierkante plaat kunnen benaderen met de capaciteit voor een disk condensator.

# %% [markdown]
# #### Vraag 6b2: Capaciteit van een condensator met het edge effect meegenomen
#
# Vanaf hier nemen we aan dat factor van de circulaire platen ongeveer gelijk is aan de factor voor vierkante platen. De factor die de capaciteit van de vlakke plaat approximatie linkt aan de werkelijke capaciteit noemen we vanaf nu de idealiteitsfactor.
#
# 1. Bereken de daadwerkelijke theoretische capaciteit van de condensator uit de sanity check 3 van de fysieke ontwerpopdracht en print deze op een nette manier.
# 2. Vergelijk dit met de daadwerkelijke theoretische capaciteit met de capaciteit die je op de dag zelf hebt gemeten.
#
# Vanaf hier gaan we verder met jullie sensor van de ontwerpopdracht "Maak een sensor met condensatoren":
#
# 3. Reken je theoretische kalibratie grafiek om met de idealiteitsfactor.
# 4. Vergelijk je nieuwe theoretische kalibratiegrafiek van je praktische kalibratiegrafiek van de dag zelf.

# %%
# Schrijf hier jouw code die de vlakke plaat capaciteit omschrijft naar de werkelijke capaciteit

import numpy as np  
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit    


#De berekeningen van sanity check 3 van de fysieke ontwerpopdracht:

def functieNaam(oppervlakte, afstand, diëlektrische_constante):
    epsilon_0 = 8.854187817e-12  
    
    # Formule: C = ε0 * εr * A / d
    output = epsilon_0 * diëlektrische_constante * oppervlakte / afstand
    
    return output

oppervlakte_test= 0.01  # in vierkante meters, 10 bij 10 cm
afstand_test = 0.0022  # in meters, 1 mm
diëlektrische_constante_test = 2  # voor papier 3, voor lucht 1. Gewogen met hoe weinig papier er is, schatten wij het op 2
C = [functieNaam(oppervlakte_test, afstand_test, diëlektrische_constante_test)]


print(f"Berekende capaciteit plaatcondensator groep 56 is", C, "Farad")
print(f"Dit komt overeen met {C[0]*1e12:.1f} pF als capaciteit")

Vin= 8 # in Volt
Ceind= 80.5e-12 # in Farad
f= 100000 # in Hz
Rshunt= 1000 # in Ohm


Vout= Vin*2*np.pi*f*Ceind*Rshunt
print(f"De verwachte uitgangsspanning is {Vout:.2f} Volt")

#Berekenen van de werkelijke capaciteit van een vlakke plaat condensator met een oppervlakte van 0.01 m^2, een afstand van 0.0022 m en een relatieve permittiviteit van 2, rekening houdend met rand effecten.

def C_niet_ideaal(S, d, epsilon_r):
    epsilon_0 = 8.854187817e-12
    w = np.sqrt(S) # breedte van de vierkante plaat
    b = d / w      # aspectratio
    
    # Ideale capaciteit (C0)
    C0 = (epsilon_0 * epsilon_r * S) / d
    
    # Correctiefactor (CSN) voor vierkante platen (Nishiyama & Nakamura Eq. 29)
    # Voor b < 0.1 gebruiken we de trendlijn van de studie
    C_sn_factor = 1 + 2.343 * (b**0.891)
    
    actual_C = C0 * C_sn_factor
    return C0, actual_C, b

# Input uit sanity check
S_test = 0.01
d_test = 0.0022
er_test = 2

C0, C_actual, b_val = C_niet_ideaal(S_test, d_test, er_test)

print(f"--- Resultaten Gecorrigeerde Capaciteit ---")
print(f"Aspectratio (b):              {b_val:.4f}")
print(f"Ideale capaciteit (C0):       {C0*1e12:.2f} pF")
print(f"Correctiefactor (Edge effect): {C_actual/C0:.4f}")
print(f"Daadwerkelijke theoretische C: {C_actual*1e12:.2f} pF")


#idealiteitsfactor = C_actual / C0
idealiteitsfactor = C_actual / C0
print(f"De idealiteitsfactor van de condensator is: {idealiteitsfactor:.4f}")


#omrekenen van de theoretische calibaratiegrafiek naar de werkelijke capaciteit:

import numpy as np
import matplotlib.pyplot as plt

# Parameters uit de studie en sanity check
epsilon_0 = 8.854187817e-12
epsilon_r = 1.0  
S = 0.01         
w = 0.1          
z0 = 0.015       # 15 mm startafstand
k = 4.335e-6     # Geschatte samendrukking in m/g

# Massa range
m = np.linspace(0, 3345, 100)
d = z0 - k * m   # De afstand d als functie van massa m

# Berekening met Edge Effect (Nishiyama & Nakamura Eq. 29)
b = d / w
C0 = (epsilon_0 * epsilon_r * S) / d
C_theory = C0 * (1 + 2.343 * (b**0.891))

m1= 973.3
m2=972.2
m3= 938.1
m4= 461.3
M = np.array([0, m4,m1+m4,m1+m3,m1+m2,m1+m3+m4,m1+m2+m3,m1+m2+m3+m4])
C = np.array([150,185,208, 238, 250, 465, 750, 875])*1e-12

def fitfunctie(C, a, b):
    return a-b/C
curve_fit(fitfunctie, C, M)
popt, pcov = curve_fit(fitfunctie, C, M)
a_fit, b_fit = popt
x_fit = np.linspace(np.min(C), np.max(C), 100)
y_fit = fitfunctie(x_fit, a_fit, b_fit)

# Plotten
plt.figure(figsize=(10, 6))
plt.plot(C_theory * 1e12, m, 'r-', label='Theoretisch Model (incl. Edge Effect)')
plt.errorbar(C*1e12, M, yerr=0.5, xerr=0.01*C*1e12, fmt='o', label='Gemeten data')
plt.plot(x_fit*1e12, y_fit, '-', label=f'Fit: m = {a_fit:.2f} * C + {b_fit:.2f}')
plt.xlabel("Capaciteit (pF)")
plt.ylabel("Massa (g)")
plt.title("Theoretische Kalibratiegrafiek: Massa als functie van Capaciteit")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show()

print(f"Theoretisch bereik: {min(C_theory*1e12):.2f} pF tot {max(C_theory*1e12):.2f} pF")
# Out:
# Berekende capaciteit plaatcondensator groep 56 is [8.049261651818181e-11] Farad
# Dit komt overeen met 80.5 pF als capaciteit
# De verwachte uitgangsspanning is 0.40 Volt
# --- Resultaten Gecorrigeerde Capaciteit ---
# Aspectratio (b):              0.0220
# Ideale capaciteit (C0):       80.49 pF
# Correctiefactor (Edge effect): 1.0781
# Daadwerkelijke theoretische C: 86.78 pF
# De idealiteitsfactor van de condensator is: 1.0781
# Theoretisch bereik: 8.45 pF tot 180.98 pF

# %% [markdown]
# ##### Antwoorden 6b2
#
# *Doe in deze markdown cel je vergelijkingen voor de sanity check condensator en je kalibratiegrafiek.*.
#
# $C = \epsilon_{\theta} \cdot \epsilon_{r} \cdot \frac{A}{d}$
#
# $d = z_0 - k \cdot m$

# %% [markdown]
# #### Vraag 6c: Niet linear diëlektricum optie 1
#
# Niet alle materialen zijn een lineair diëlektricum. Een aantal van de materialen die sterk niet lineair gedrag vertonen zijn: sponzen, foam & rubber. Als je in je opdracht een materiaal gebruikt heb waarvan je verwacht dat het verband sterk niet lineair is kan dit een hele goede opdracht zijn.
# | Materiaal |$\chi_2$   |
# | :-------------|:-------------|
# | Spons|  |
#
# Als jouw materiaal hier niet tussen staat dan kan je zelf op zoek naar een waarde van $\chi_2$ in de literatuur.

# %% [markdown]
# #### Vraag 6c1
#
# 1. Leidt het D veld van de condensator af uit de wet van Gauss.
# 2. Vindt een analytische uitdrukking voor het elektrisch veld in termen van het D veld.

# %% [markdown]
# ##### Antwoorden 6c 1
#
# *Antwoord vraag 6c 1.*

# %% [markdown]
# #### Vraag 6c2
#
# 1. Programmeer je oplossingen voor het D en E veld in python, gebruik het D veld uit je fysieke ontwerpopdracht.
#
# Als je het elektrische veld van een vierkante vlakke plaat condensator weet kan je de capaciteit berekenen met de onderstaande formule:
# $C = \frac{A
# E_z \epsilon_0}{\Delta V}$
#
# 2. Plot de capaciteit van het niet lineaire diëlektricum, het theoretische kalibratiegrafiek en de uiteindelijke kalibratiegrafiek van de fysieke ontwerpopdracht.
# 3. Verklaar verschillen tussen de grafieken.

# %%
 # Pas deze code aan zodat jouw opstelling doorgerekend wordt
def E_condensator(x1, x2, D):
    return None

# %% [markdown]
# #### Vraag 7
#
# Hoeveel van de afwijking tussen je metingen en je oorspronkelijke voorspelde kalibratiegrafiek wordt verklaard door wat je bij vraag 6 hebt uitgerekend? Kan je een (aantal) elektrisch veld en capaciteit gerelateerde reden(en) verzinnen wat de rest van de afwijking tussen meting en voorspelde kalibratiegrafiek kan verklaren.

# %% [markdown]
# ##### Antwoorden 7
#
# Het verklaart heel weinig van de afwijking. De afwijking werd gecorrigeerd met een factor van ongeveer 1.07, hoewel de afwijking van de daadwerkelijke calibratie met de gecorrigeerde theoretische calibratiegrafiek misschien wel een factor 10 was. Ik heb zitten zoeken naar fouten in de berekningen die waren gemaakt op de dag van de fysiekeontwerpopdracht, maar alles zag er in orde uit. Wat ik denk dat een grote invloed zou kunnen hebben gehad op de daadwerkelijk gemeten kalibratiewaarden is parasitaire capaciteit. De kabels en connecties rondom je opstelling gedragen zich ook als condensatoren en zouden uiteindelijk een grote invloed hebben op je metingen. Ook zouden de objecten rondom de metalen platen invloed kunnen hebben gehad om de edge effect: onze platen zaten geklemd tussen twee sponsen en de bovenste plaat was getapet aan een houten lat.
