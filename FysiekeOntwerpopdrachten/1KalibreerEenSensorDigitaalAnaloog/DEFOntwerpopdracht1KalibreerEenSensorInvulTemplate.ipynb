# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 14     |  |
# | :-------------|:-------------|
# | Wolf Peutz| 6436102 |
# | Alek Janssen| 6570224 |
# | Abenezer Bayu| 6268315 |
#
# | Planning Groep: 14     |Tijdstip / Tijdspanne  |
# |---|---|
# | Mijlpaal 1: Een sensor gekozen hebben + toepassing | 10:45 – 12:30 |
# | schetsen  | 11:00-11:30 |
# | een gekozen hebben + evaluatie| 12:00  |
# | Mijlpaal 2: Bouwen + meten|     13:45 – 16:00  |
# | Mijlpaal 3: Data en informatie verwerken | 16:00 – 16:45 |
# | Mijlpaal 4: Feedback verwerken en opruimen | 16:45 – 17:45 |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#
# ![Alt](P1.png "analyse: ideeen")
# ![Alt](P2.png "analyse: ideeen")

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |LSR | Sensor voor Afstandsbediening | Hij moet een juiste range van golflengten af kunnen meten (De afstandsbediening gebruikt IR licht, wat ongeveer gelijk staat aan een range van golflenten van 850-950 nm. Alle waardes tussen 850 en 950 nm voldoen).   |
# |LSR | Sensor voor Afstandsbediening | Een kleine tijdsinterval voor meten; de afstandsbediening zou in 0.1 seconden een 'code' verzenden. We schatten dat dit gelijk kan staan aan 100 lichtpulsen. Dat betekent dus dat er gemiddeld elke 0.001 seconden een puls is.  Om zeker te zijn van een juiste interval voor het meten delen we 0.001 met 10. Dit betekent dat het interval waarop de lichtsensor zou moeten meten kleiner moet zijn dan 0.0001 seconden.|
# |LSR | Sensor voor Afstandsbediening | Hij moet gevoelig genoeg zijn voor zwakke lichtpulsen; minstens $10^{-6} W/m^2$. Hij moet niet verzadigen bij een IR intensiteit van $1 W/m^2$ |
# |Krachtsensor | Weegschaal | Dat de sensor stabiel staat op een vlakke ondergrond (maximaal 1 graad afwijjking van perfect recht (geen gradient t.o.v. de zwaartekracht)) |
# |Krachtsensor | Weegschaal | Dat er een vast te leggen verband is tussen de aangegeven bits en het gewogen gewicht |
# |Krachtsensor | Weegschaal | Hij kan een gewicht tussen 10 en 500 gram meten met een nauwkeurigheid van 1 gram |
# |Temperatuursensor | Lichaamstemperatuurmeter | Hij kan tussen 33 en 43 graden C meten met een nauwkeurigheid van 0.1 C|
# |Temperatuursensor | Lichaamstemperatuurmeter | Hij moet passen binnen het formaat 1cm x 1cm x 10cm |
# |Temperatuursensor | Lichaamstemperatuurmeter | Hij is waterdicht (minimaal IPX 7); functioneel bij onderdompeling in water tot 1 meter voor minstens 30 minuten.|
#
# Groep XX heeft gekozen voor sensor YY.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Licht kort toe wat er in de foto te zien is:
# In de foto is te zien dat de indruksensor verbonden is met een spanningsdeler. Verder is de telefoon ter ondersteuning onder de druksensoor gelegd. Een pen dop is op de druksensoor gelegd omdat er gemerkt is dat anders wanneer een object erop wordt gelegd geen meting waargenomen is. Er is tape gebruikt om de dop op zijn plek te houden omdat er ook gemeten is dat de plek van de dop invloed heeft op de metingen.
#
#  ![Alt](P4.png "schets student")

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen?
#         Het gewicht
# 2. Over welk bereik ga je deze variabelen veranderen?
#         20 tot 600g gram
# 3. Wat ga je allemaal meten?
#         De bit-waarde van de arduino
# 4. Hoeveel metingen ga je doen?
#         7
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?
#         Ja

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Op de foto is een arduino boord te zien die verbonden is aan de laptop. Aan de arduino is een breadboard verbonden met een weerstand in serie geschakelt met een krachtgevoelige weerstand. Deze krachtsensor is vastgetapet aan een telefoon (als platte verheven bodem). direct op de sensor zit een dop van een pen die gebruikt wordt als een basis om op te meten. De waterfles wordt gebruikt als een variabele gewicht.
#  ![Alt](P5.png "meetopstelling student")
#   ![Alt](P6.png "meetopstelling student")

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
import matplotlib.pyplot as plt

x = np.array([512.43, 446.32, 391.27, 326.42, 272.54, 255.41, 223.73])
y = np.array([922, 914, 912, 888, 872, 821, 780])

# %%
# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.

import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def fitfunt(x, a, b):
    return a*np.log(x) + b
popt, pcov = curve_fit(fitfunt, x, y)
u_x = 0.02
u_y=0.1


plt.errorbar(x,y, xerr=u_x, yerr=u_y, fmt= '.', label='Data')
plt.title('Kalibratie van de sensor')
plt.plot(x, fitfunt(x, *popt), '--', label='Fit')
plt.ylabel('Bit-waarde (#)')
plt.xlabel('Gewicht (g)')    
plt.legend()
plt.show()



# %matplotlib inline

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# Nee

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# Aan onze gegevens is te zien dat de krachtsensor inderdaad een positief stijgend verband aangeeft. Dit is niet een lineair verband helaas. Met juiste calibratie en het lineariseren van het verband tussen de bits en het gewicht kan deze krachtsensor inderdaad goed gebruikt worden voor een weegschaal. De afwijking van de meetwaarden van de fit toont aan dat onze metingen nogal onnauwkeurig blijven. Onze meetwaarden voldoen wel aan onze verwachting voor de nauwkeurigheid. Onze manier om gewicht te meten was te verwacten onnauwkeurig.
#
# samenvattend: Criteria 1 en 2 zijn gehaald aangezien er een duidelijk stijgend verband is en de opstelling stabiel genoeg is om metingen te verichten. helaas is criteria 3 niet behaald omdat de meetpunten te ver van de fitlijn afliggen

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Licht kort toe wat er in de foto te zien is:
# In de foto is te zien dat de indruksensor verbonden is met een spanningsdeler. Verder is de telefoon ter ondersteuning onder de druksensoor gelegd. Een pen dop is op de druksensoor gelegd omdat er gemerkt is dat anders wanneer een object erop wordt gelegd geen meting waargenomen is. Er is tape gebruikt om de dop op zijn plek te houden omdat er ook gemeten is dat de plek van de dop invloed heeft op de metingen.
#
#  ![Alt](P4.png "schets student")
#
#  ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Op de foto is een arduino boord te zien die verbonden is aan de laptop. Aan de arduino is een breadboard verbonden met een weerstand in serie geschakelt met een krachtgevoelige weerstand. Deze krachtsensor is vastgetapet aan een telefoon (als platte verheven bodem). direct op de sensor zit een dop van een pen die gebruikt wordt als een basis om op te meten. De waterfles wordt gebruikt als een variabele gewicht.
#  ![Alt](P5.png "meetopstelling student")
#   ![Alt](P6.png "meetopstelling student")

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |LSR | Sensor voor Afstandsbediening | Hij moet een juiste range van golflengten af kunnen meten (De afstandsbediening gebruikt IR licht, wat ongeveer gelijk staat aan een range van golflenten van 850-950 nm. Alle waardes tussen 850 en 950 nm voldoen).   |
# |LSR | Sensor voor Afstandsbediening | Een kleine tijdsinterval voor meten; de afstandsbediening zou in 0.1 seconden een 'code' verzenden. We schatten dat dit gelijk kan staan aan 100 lichtpulsen. Dat betekent dus dat er gemiddeld elke 0.001 seconden een puls is.  Om zeker te zijn van een juiste interval voor het meten delen we 0.001 met 10. Dit betekent dat het interval waarop de lichtsensor zou moeten meten kleiner moet zijn dan 0.0001 seconden.|
# |LSR | Sensor voor Afstandsbediening | Hij moet gevoelig genoeg zijn voor zwakke lichtpulsen; minstens $10^{-6} W/m^2$. Hij moet niet verzadigen bij een IR intensiteit van $1 W/m^2$ |
# |Krachtsensor | Weegschaal | Dat de sensor stabiel staat op een vlakke ondergrond (maximaal 1 graad afwijjking van perfect recht (geen gradient t.o.v. de zwaartekracht)) |
# |Krachtsensor | Weegschaal | Dat er een vast te leggen verband is tussen de aangegeven bits en het gewogen gewicht |
# |Krachtsensor | Weegschaal | Hij kan een gewicht tussen 10 en 500 gram meten met een nauwkeurigheid van 1 gram |
# |Temperatuursensor | Lichaamstemperatuurmeter | Hij kan tussen 33 en 43 graden C meten met een nauwkeurigheid van 0.1 C|
# |Temperatuursensor | Lichaamstemperatuurmeter | Hij moet passen binnen het formaat 1cm x 1cm x 10cm |
# |Temperatuursensor | Lichaamstemperatuurmeter | Hij is waterdicht (minimaal IPX 7); functioneel bij onderdompeling in water tot 1 meter voor minstens 30 minuten.|
#
# Groep XX heeft gekozen voor sensor YY.

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen?
#         Het gewicht
# 2. Over welk bereik ga je deze variabelen veranderen?
#         20 tot 600g gram
# 3. Wat ga je allemaal meten?
#         De bit-waarde van de arduino
# 4. Hoeveel metingen ga je doen?
#         7
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?
#         Ja

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Licht kort toe wat er in de foto te zien is:
# In de foto is te zien dat de indruksensor verbonden is met een spanningsdeler. Verder is de telefoon ter ondersteuning onder de druksensoor gelegd. Een pen dop is op de druksensoor gelegd omdat er gemerkt is dat anders wanneer een object erop wordt gelegd geen meting waargenomen is. Er is tape gebruikt om de dop op zijn plek te houden omdat er ook gemeten is dat de plek van de dop invloed heeft op de metingen.
#
#  ![Alt](P4.png "schets student")
#
#  ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Op de foto is een arduino boord te zien die verbonden is aan de laptop. Aan de arduino is een breadboard verbonden met een weerstand in serie geschakelt met een krachtgevoelige weerstand. Deze krachtsensor is vastgetapet aan een telefoon (als platte verheven bodem). direct op de sensor zit een dop van een pen die gebruikt wordt als een basis om op te meten. De waterfles wordt gebruikt als een variabele gewicht.
#  ![Alt](P5.png "meetopstelling student")
#   ![Alt](P6.png "meetopstelling student")
#
#   ## *Opdracht 8*: Conclusie, leerdoel
#
# Aan onze gegevens is te zien dat de krachtsensor inderdaad een positief stijgend verband aangeeft. Dit is niet een lineair verband helaas. Met juiste calibratie en het lineariseren van het verband tussen de bits en het gewicht kan deze krachtsensor inderdaad goed gebruikt worden voor een weegschaal.

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
import matplotlib.pyplot as plt

x = np.array([512.43, 446.32, 391.27, 326.42, 272.54, 255.41, 223.73])
y = np.array([922, 914, 912, 888, 872, 821, 780])


# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.

import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def fitfunt(x, a, b):
    return a*np.log(x) + b
popt, pcov = curve_fit(fitfunt, x, y)

plt.plot(x,y, '.', label='Data')
plt.title('Kalibratie van de sensor')
plt.plot(x, fitfunt(x, *popt), '--', label='Fit')
plt.ylabel('Bit-waarde (#)')
plt.xlabel('Gewicht (g)')    
plt.legend()
plt.show()



# %matplotlib inline
